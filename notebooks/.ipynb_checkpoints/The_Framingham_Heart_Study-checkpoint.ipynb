# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
from numpy import mean
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.tree import DecisionTreeClassifier
from imblearn.pipeline import Pipeline
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler

# %%
framingham = pd.read_csv('../dataset/framingham.csv')

# %%
framingham.head()
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# ...

# %% [markdown]
# ## Exploratory Data Visualization

# %%
sns.set(style="whitegrid")

plt.figure(figsize=(8, 6))
ax = sns.countplot(x='education', data=framingham, palette='pastel')

ax.set_title('Education Level Distribution')
ax.set_xlabel('Education Level')
ax.set_ylabel('Count')

plt.plot()
# Out:
# []

# %%
sns.set(style="whitegrid")

cat_plot = sns.catplot(
    x='TenYearCHD',
    y='cigsPerDay',
    kind='bar',
    data=framingham,
    palette='pastel',
    height=6,
    aspect=1.2
)

cat_plot.fig.suptitle('Average Cigarettes Per Day by 10-Year CHD Risk', y=1.03)
cat_plot.set_axis_labels('10-Year CHD', 'Cigarettes Per Day')

plt.show()

# %%
sns.set(style="whitegrid")

plt.figure(figsize=(10, 6))
ax = sns.boxplot(x='TenYearCHD', y='age', hue='currentSmoker', data=framingham, palette='pastel')

ax.set_title('Age Distribution by CHD Status and Smoking Status')
ax.set_xlabel('10-Year CHD')
ax.set_ylabel('Age')

plt.legend(title='Current Smoker', bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
ax = sns.boxplot(x='TenYearCHD', y='age', hue='prevalentStroke', data=framingham, palette='pastel')

ax.set_title('Age Distribution by CHD Status and Stroke History')
ax.set_xlabel('10-Year CHD')
ax.set_ylabel('Age')

plt.legend(title='Prevalent Stroke', bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
ax = sns.boxplot(x='TenYearCHD', y='age', hue='diabetes', data=framingham, palette='pastel')

ax.set_title('Age Distribution by CHD Status and Diabetes')
ax.set_xlabel('10-Year CHD')
ax.set_ylabel('Age')

plt.legend(title='Diabetes', bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
ax = sns.boxplot(x='TenYearCHD', y='totChol', data=framingham, palette='pastel')

ax.set_title('Total Cholesterol by CHD Status')
ax.set_xlabel('10-Year CHD')
ax.set_ylabel('Total Cholesterol')

plt.ylim(80)
plt.tight_layout()
plt.show()

# %%
cat_plot = sns.catplot(
    x='TenYearCHD',
    y='sysBP',
    kind='bar',
    data=framingham,
    palette='pastel',
    height=6,
    aspect=1.2
)

cat_plot.fig.suptitle('Average Systolic Blood Pressure by 10-Year CHD Risk', y=1.03)
cat_plot.set_axis_labels('10-Year CHD', 'Systolic Blood Pressure')

plt.show()

# %%
cat_plot = sns.catplot(
    x='TenYearCHD',
    y='diaBP',
    kind='bar',
    data=framingham,
    palette='pastel',
    height=6,
    aspect=1.2
)

cat_plot.fig.suptitle('Average Diastolic Blood Pressure by 10-Year CHD Risk', y=1.03)
cat_plot.set_axis_labels('10-Year CHD', 'Diastolic Blood Pressure')

plt.show()

# %%
cat_plot = sns.catplot(
    x='TenYearCHD',
    y='BMI',
    kind='bar',
    data=framingham,
    palette='pastel',
    height=6,
    aspect=1.2
)

cat_plot.fig.suptitle('Average BMI by 10-Year CHD Risk', y=1.03)
cat_plot.set_axis_labels('10-Year CHD', 'BMI')

plt.show()

# %%
cat_plot = sns.catplot(
    x='TenYearCHD',
    y='BPMeds',
    kind='bar',
    data=framingham,
    palette='pastel',
    height=6,
    aspect=1.2
)

cat_plot.fig.suptitle('Average Use of Blood Pressure Medication by 10-Year CHD Risk', y=1.03)
cat_plot.set_axis_labels('10-Year CHD', 'Blood Pressure Medication Use')

plt.show()

# %% [markdown]
# ## Data Preprocessing

# %%
# Checking for null values
framingham.isnull().any()
# Out:
# male               False
# age                False
# education           True
# currentSmoker      False
# cigsPerDay          True
# BPMeds              True
# prevalentStroke    False
# prevalentHyp       False
# diabetes           False
# totChol             True
# sysBP              False
# diaBP              False
# BMI                 True
# heartRate           True
# glucose             True
# TenYearCHD         False
# dtype: bool

# %%
# Dropping null values
framingham = framingham.dropna()

# %%
framingham.isnull().any()
# Out:
# male               False
# age                False
# education          False
# currentSmoker      False
# cigsPerDay         False
# BPMeds             False
# prevalentStroke    False
# prevalentHyp       False
# diabetes           False
# totChol            False
# sysBP              False
# diaBP              False
# BMI                False
# heartRate          False
# glucose            False
# TenYearCHD         False
# dtype: bool

# %%
framingham['TenYearCHD'].value_counts()
# Out:
# TenYearCHD
# 0    3101
# 1     557
# Name: count, dtype: int64

# %%
# Baseline accuracy:
3101/(3101+557)
# Out:
# 0.8477310005467469

# %% [markdown]
# ## Train-Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X = framingham.drop('TenYearCHD',axis=1)
y = framingham['TenYearCHD']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.35)

# %% [markdown]
# ## Oversampling and Undersampling

# %%
oversample = RandomOverSampler(sampling_strategy='minority')
X_over, y_over = oversample.fit_resample(X, y)
X_train, X_test, y_train, y_test = train_test_split(X_over,y_over,test_size=0.35)

# %%
steps = [('under', RandomUnderSampler()), ('model', DecisionTreeClassifier())]
pipeline = Pipeline(steps=steps)

# %% [markdown]
# ## Fitting the data to the pipeline

# %%
pipeline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('under', RandomUnderSampler()),
#                 ('model', DecisionTreeClassifier())])

# %% [markdown]
# ## Making predictions on test data

# %%
pipepred = pipeline.predict(X_test)

# %% [markdown]
# ## Evaluating the model

# %%
from sklearn.metrics import classification_report,accuracy_score
print(classification_report(y_test,pipepred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.80      0.88      1065
#            1       0.84      0.97      0.90      1106
#
#     accuracy                           0.89      2171
#    macro avg       0.90      0.89      0.89      2171
# weighted avg       0.90      0.89      0.89      2171

# %%
accuracy_score(y_test,pipepred)
# Out:
# 0.8876093965914326

# %% [markdown]
# The model has high precision and recall for both outcomes, and has an accuracy of 0.90, which beats the baseline.
